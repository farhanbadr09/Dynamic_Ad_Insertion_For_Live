# %%
#Sou;
from bs4 import BeautifulSoup


# Reading the data inside the xml, file to a variable under the name, data
with open('mpd', 'r' , encoding='utf-8', errors='ignore') as f:
	data = f.read()

# Passing the stored data inside, the beautifulsoup parser, storing ,the returned object
Bs_data = BeautifulSoup(data, "xml")

# Finding all instances of tag
for postcode_tag in Bs_data.find_all("BaseURL"):
    postcode_tag.string = "farhan.com"
    
with open("usman.xml", "w") as outfile:
    outfile.write(Bs_data.prettify())
# Using find() to extract attributes
# of the first instance of the tag
# b_name = Bs_data.find('child', {'name':'Frank'})

# print(b_name)

# Extracting the data stored in a
# specific attribute of the
# `child` tag
# value = b_name.get('test')

# print(value)

# %%
Bs_data
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <MPD availabilityStartTime="1970-01-01T00:00:00Z" maxSegmentDuration="PT3S" minBufferTime="PT2S" minimumUpdatePeriod="PT2S" profiles="urn:mpeg:dash:profile:isoff-live:2011,urn:hbbtv:dash:profile:isoff-live:2012" publishTime="2021-10-10T07:16:58Z" timeShiftBufferDepth="PT5M" type="dynamic" xmlns:="urn:mpeg:dash:schema:mpd:2011" xmlns:daiconnect="urn:daiconnect:dai:2019:xml" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="urn:mpeg:dash:schema:mpd:2011 http://standards.iso.org/ittf/PubliclyAvailableStandards/MPEG-DASH_schema_files/DASH-MPD.xsd">
# <Period duration="PT1M16.992000S" id="110298" start="PT453847H10M43.012124S">
# <BaseURL>https://live.unified-streaming.com/scte35/scte35.isml/dash/</BaseURL>
# <AdaptationSet audioSamplingRate="48000" codecs="mp4a.40.2" contentType="audio" group="1" id="1" mimeType="audio/mp4" segmentAlignment="true" startWithSAP="1">
# ...

# %%
print(json.loads(Bs_data))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11704/2751862292.py in <module>
# ----> 1 print(json.loads(Bs_data))
#
# ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not BeautifulSoup

# %%
import xml.etree.ElementTree as ET
filename = "a_file.xml"
xmlTree = ET.parse(filename)
rootElement = xmlTree.getroot()
change = "https://live.unified-streaming.com//scte35.isml/dash/"
for element in rootElement.findall("BaseURL"):
    print("da")
    #Find the book that has title as 'Python Tutorial'
#     if element.text == change :
#         #Change the price
#         element.text = "50.00"
#     else:
#         print("Not Fou")
# #Write the modified xml file.        
# xmlTree.write(filename,encoding='UTF-8',xml_declaration=True)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\jkk\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\jkk\AppData\Local\Temp/ipykernel_11704/464194798.py", line 3, in <module>
#     xmlTree = ET.parse(filename)
#
#   File "C:\Users\jkk\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py", line 1229, in parse
#     tree.parse(source, parser)
#
#   File "C:\Users\jkk\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py", line 580, in parse
#     self._root = parser._parse_whole(source)
#
#   File "<string>", line unknown
# ParseError: no element found: line 1, column 0

# %%
pip install xmltodict
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\jkk\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import xmltodict, json

obj = xmltodict.parse("a_file.xml")
print(json.dumps(obj))
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11704/3083430339.py in <module>
#       1 import xmltodict, json
#       2
# ----> 3 obj = xmltodict.parse("a_file.xml")
#       4 print(json.dumps(obj))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, **kwargs)
#     325         parser.ParseFile(xml_input)
#     326     else:
# --> 327         parser.Parse(xml_input, True)
#     328     return handler.item
#     329
#
# ExpatError: syntax error: line 1, column 0

# %%
# f = open("a_file.xml", "r")
# a = f.read()
str(Bs_data)
# Out:
# '<?xml version="1.0" encoding="utf-8"?>\n<MPD availabilityStartTime="1970-01-01T00:00:00Z" maxSegmentDuration="PT3S" minBufferTime="PT2S" minimumUpdatePeriod="PT2S" profiles="urn:mpeg:dash:profile:isoff-live:2011,urn:hbbtv:dash:profile:isoff-live:2012" publishTime="2021-10-10T07:16:58Z" timeShiftBufferDepth="PT5M" type="dynamic" xmlns:="urn:mpeg:dash:schema:mpd:2011" xmlns:daiconnect="urn:daiconnect:dai:2019:xml" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="urn:mpeg:dash:schema:mpd:2011 http://standards.iso.org/ittf/PubliclyAvailableStandards/MPEG-DASH_schema_files/DASH-MPD.xsd">\n<Period duration="PT1M16.992000S" id="110298" start="PT453847H10M43.012124S">\n<BaseURL>https://live.unified-streaming.com/scte35/scte35.isml/dash/</BaseURL>\n<AdaptationSet audioSamplingRate="48000" codecs="mp4a.40.2" contentType="audio" group="1" id="1" mimeType="audio/mp4" segmentAlignment="true" startWithSAP="1">\n<AudioChannelConfiguration schemeIdUri="urn:mpeg:dash:23003:3
# ...

# %%
import xmltodict, json

obj = xmltodict.parse(str(Bs_data))
b = json.dumps(obj)
stud_obj = json.loads(b)

print("The type of object is: ", type(stud_obj))

# for i in json_obj:
# Out:
# The type of object is:  <class 'dict'>

# %%
type(Bs_data)
# Out:
# bs4.BeautifulSoup

# %%
from bs4 import BeautifulSoup
from requests import get
from bs2json import bs2json



converter = bs2json()


json = converter.convert(Bs_data)
print(json)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11704/2137371582.py in <module>
#       8
#       9
# ---> 10 json = converter.convert(Bs_data)
#      11 print(json)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\bs2json\bs2json.py in convert(self, element, json)
#       9                         return json
#      10                 else:
# ---> 11                         raise TypeError(f"convert(x,y) `x` argument must be a {Element.__name__} not {type(element).__name__}")
#      12
#      13         def convertAll(self,elements,L=None):
#
# TypeError: convert(x,y) `x` argument must be a bs4.element not BeautifulSoup

# %%
import xml.etree.ElementTree
a_variable = xml.etree.ElementTree.parse("a_file.xml")

update = xml.etree.ElementTree.SubElement(a_variable.getroot(), "a_tag")

# %%
update.text = "new_text"
update.attrib["key"] = "value"

a_variable.write("file.xml")

print(xml.etree.ElementTree.tostring(update, encoding = "unicode"))
# Out:
# <a_tag key="value">new_text</a_tag>

# %%
with open("mpd") as f:
    print(f.read())
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# <ns0:MPD xmlns:ns0="urn:mpeg:dash:schema:mpd:2011" xmlns:ns2="urn:daiconnect:dai:2019:xml" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="urn:mpeg:dash:schema:mpd:2011 http://standards.iso.org/ittf/PubliclyAvailableStandards/MPEG-DASH_schema_files/DASH-MPD.xsd" profiles="urn:mpeg:dash:profile:isoff-live:2011,urn:hbbtv:dash:profile:isoff-live:2012" type="dynamic" availabilityStartTime="1970-01-01T00:00:00Z" publishTime="2021-10-10T07:16:58Z" minimumUpdatePeriod="PT2S" minBufferTime="PT2S" timeShiftBufferDepth="PT5M" maxSegmentDuration="PT3S">
#   <ns0:Period id="110298" start="PT453847H10M43.012124S" duration="PT1M16.992000S">
#     <ns0:BaseURL>https://live.unified-streaming.com/scte35/scte35.isml/dash/</ns0:BaseURL>
#     <ns0:AdaptationSet audioSamplingRate="48000" mimeType="audio/mp4" codecs="mp4a.40.2" startWithSAP="1" id="1" group="1" contentType="audio" segmentAlignment="true">
# ...
